# %% [markdown]
# # Ceci est un exemple d'utilisation de Jupyter
#
# On peut saisir du texte en **markdown** et mettre du code python.

# %%
print("On peut saisir du texte en **markdown** et mettre du code python.")
# Out:
# On peut saisir du texte en **markdown** et mettre du code python.

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('Quelques valeurs')
plt.show()
